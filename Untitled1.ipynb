# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.float_format', lambda x: '%.5f' % x)
pd.set_option('display.max_colwidth', 1000)

# %%
# thoughts
# predict using dx from drugs
# predict using drugs themselves
# look at families of drugs, e.g. opioids
# predict using history dx

# other library for reading files - try glob

# %%
questions = pd.read_excel('history-questions.xlsx')

# %%
demo_j = pd.read_sas('data/demo_j.xpt')
acq_j = pd.read_sas('data/acq_j.xpt')

# %%
alq_j = pd.read_sas('data/alq_j.xpt')

# %%
auq_j = pd.read_sas('data/auq_j.xpt')

# %%
bpq_j = pd.read_sas('data/bpq_j.xpt')

# %%
cdq_j = pd.read_sas('data/cdq_j.xpt')

# %%
dbq_j = pd.read_sas('data/dbq_j.xpt')

# %%
diq_j = pd.read_sas('data/diq_j.xpt')

# %%
duq_j = pd.read_sas('data/duq_j.xpt')

# %%
ecq_j = pd.read_sas('data/ecq_j.xpt')

# %%
heq_j = pd.read_sas('data/heq_j.xpt')

# %%
hsq_j = pd.read_sas('data/hsq_j.xpt')

# %%
kiq_u_j = pd.read_sas('data/kiq_u_j.xpt')
mcq_j = pd.read_sas('data/mcq_j.xpt')

# %%
ocq_j = pd.read_sas('data/ocq_j.xpt')
ohq_j = pd.read_sas('data/ohq_j.xpt')
osq_j = pd.read_sas('data/osq_j.xpt')
rhq_j = pd.read_sas('data/rhq_j.xpt')
rxqasa_j = pd.read_sas('data/rxqasa_j.xpt')
rxq_rx_j = pd.read_sas('data/rxq_rx_j.xpt')
slq_j = pd.read_sas('data/slq_j.xpt')
smqfam_j = pd.read_sas('data/smqfam_j.xpt')
smqshs_j = pd.read_sas('data/smqshs_j.xpt')
smq_j = pd.read_sas('data/smq_j.xpt')
vtq_j = pd.read_sas('data/vtq_j.xpt')
whqmec_j = pd.read_sas('data/whqmec_j.xpt')
whq_j = pd.read_sas('data/whq_j.xpt')

# %%
rxq_rx_j.head(200)
# Out:
#            SEQN  RXDUSE                               RXDDRUG   RXDDRGID  \
# 0   93703.00000 2.00000                                   b''        b''
# 1   93704.00000 2.00000                                   b''        b''
# 2   93705.00000 1.00000     b'ENALAPRIL; HYDROCHLOROTHIAZIDE'  b'd03740'
# 3   93705.00000 1.00000                          b'MELOXICAM'  b'd04532'
# 4   93705.00000 1.00000                         b'OMEPRAZOLE'  b'd00325'
# 5   93706.00000 2.00000                                   b''        b''
# 6   93707.00000 2.00000                                   b''        b''
# 7   93708.00000 1.00000                         b'AMLODIPINE'  b'd00689'
# 8   93708.00000 1.00000                           b'LOSARTAN'  b'd03821'
# 9   93708.00000 1.00000                        b'SIMVASTATIN'  b'd00746'
# 10  93709.00000 1.00000                         b'AMLODIPINE'  b'd00689'
# 11  93709.00000 1.00000                           b'NAPROXEN'  b'd00019'
# ...

# %%
rxq_rx_j.head(200)
# Out:
#            SEQN  RXDUSE                               RXDDRUG   RXDDRGID  \
# 0   93703.00000 2.00000                                   b''        b''
# 1   93704.00000 2.00000                                   b''        b''
# 2   93705.00000 1.00000     b'ENALAPRIL; HYDROCHLOROTHIAZIDE'  b'd03740'
# 3   93705.00000 1.00000                          b'MELOXICAM'  b'd04532'
# 4   93705.00000 1.00000                         b'OMEPRAZOLE'  b'd00325'
# 5   93706.00000 2.00000                                   b''        b''
# 6   93707.00000 2.00000                                   b''        b''
# 7   93708.00000 1.00000                         b'AMLODIPINE'  b'd00689'
# 8   93708.00000 1.00000                           b'LOSARTAN'  b'd03821'
# 9   93708.00000 1.00000                        b'SIMVASTATIN'  b'd00746'
# 10  93709.00000 1.00000                         b'AMLODIPINE'  b'd00689'
# 11  93709.00000 1.00000                           b'NAPROXEN'  b'd00019'
# ...

# %%
rxq_rx_j.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19643 entries, 0 to 19642
# Data columns (total 13 columns):
# SEQN        19643 non-null float64
# RXDUSE      19643 non-null float64
# RXDDRUG     19643 non-null object
# RXDDRGID    19643 non-null object
# RXQSEEN     14311 non-null float64
# RXDDAYS     14309 non-null float64
# RXDRSC1     19643 non-null object
# RXDRSC2     19643 non-null object
# RXDRSC3     19643 non-null object
# RXDRSD1     19643 non-null object
# RXDRSD2     19643 non-null object
# RXDRSD3     19643 non-null object
# RXDCOUNT    14434 non-null float64
# dtypes: float64(5), object(8)
# memory usage: 1.9+ MB

# %%
# RXDUSE	Taken prescription medicine, past month	In the past 30 days, have you used or taken medication for which a prescription is needed? Do not include prescription vitamins or minerals you may have already told me about.	Prescription Medications (RXQ_RX_J)	2017-2018 Questionnaire

rxq_rx_j['RXDUSE'].value_counts()
# Out:
# 1.00000    14434
# 2.00000     5198
# 9.00000        6
# 7.00000        5
# Name: RXDUSE, dtype: int64

# %%
rxq_rx_j['RXDDRUG'].value_counts().head(200)
# Out:
# b''                                       5209
# b'ATORVASTATIN'                            594
# b'METFORMIN'                               570
# b'LISINOPRIL'                              499
# b'AMLODIPINE'                              451
# b'METOPROLOL'                              433
# b'LEVOTHYROXINE'                           404
# b'OMEPRAZOLE'                              324
# b'LOSARTAN'                                318
# b'ALBUTEROL'                               315
# b'SIMVASTATIN'                             306
# b'GABAPENTIN'                              245
# b'HYDROCHLOROTHIAZIDE'                     213
# b'FUROSEMIDE'                              212
# b'GLIPIZIDE'                               159
# b'MONTELUKAST'                             150
# b'PANTOPRAZOLE'                            146
# b'PRAVASTATIN'                             145
# b'CLOPIDOGREL'                             141
# b'CARVEDILOL'                              139
# ...

# %%
rxq_rx_j['RXDRSD1'].value_counts().head(200)
# Out:
# b''                                                                                        5875
# b'Essential (primary) hypertension'                                                        2470
# b'Pure hypercholesterolemia'                                                               1182
# b'Type 2 diabetes mellitus'                                                                1060
# b'Major depressive disorder, single episode, unspecified'                                   497
# b'Gastro-esophageal reflux disease'                                                         432
# b'Asthma'                                                                                   363
# b'Hypothyroidism, unspecified'                                                              345
# b'Anxiety disorder, unspecified'                                                            330
# b'Dorsalgia'                                                                                271
# ...

# %%
rx_dx_df = rxq_rx_j.loc[rxq_rx_j['RXDUSE'] == 1]
rx_dx_df.reset_index(inplace=True)
rx_dx_df.drop(columns = 'index', inplace=True)
rx_dx_df = rx_dx_df[['SEQN','RXDRSD1','RXDDAYS']]
# Out:
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py:4117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
rx_dx_df
# Out:
#               SEQN                                 RXDRSD1    RXDDAYS
# 0      93705.00000     b'Essential (primary) hypertension' 5475.00000
# 1      93705.00000    b'Rheumatoid arthritis, unspecified'   61.00000
# 2      93705.00000                            b'Heartburn' 3650.00000
# 3      93708.00000     b'Essential (primary) hypertension' 1460.00000
# 4      93708.00000     b'Essential (primary) hypertension' 3650.00000
# ...            ...                                     ...        ...
# 14429 102956.00000                 b'Allergy, unspecified'    4.00000
# 14430 102956.00000        b'Anxiety disorder, unspecified'  365.00000
# 14431 102956.00000     b'Other seasonal allergic rhinitis'    4.00000
# 14432 102956.00000  b'Neuralgia and neuritis, unspecified'  365.00000
# 14433 102956.00000  b'Neuralgia and neuritis, unspecified'  365.00000
#
# [14434 rows x 3 columns]

# %%
rx_dx_df.info()

# a few have null value for days
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14434 entries, 0 to 14433
# Data columns (total 3 columns):
# SEQN       14434 non-null float64
# RXDRSD1    14434 non-null object
# RXDDAYS    14309 non-null float64
# dtypes: float64(2), object(1)
# memory usage: 338.4+ KB

# %%
rx_dx_df.loc[rx_dx_df['RXDDAYS'].isnull() == True]

# mostly rows with null days don't have real diagnoses either - drop these rows (125 rows)
# Out:
#               SEQN                              RXDRSD1  RXDDAYS
# 80     93756.00000                                  b''      nan
# 171    93804.00000                                  b''      nan
# 196    93821.00000                                  b''      nan
# 201    93826.00000                                  b''      nan
# 543    94038.00000                                  b''      nan
# 587    94055.00000                                  b''      nan
# 771    94163.00000                                  b''      nan
# 836    94212.00000                                  b''      nan
# 925    94265.00000                                  b''      nan
# 1015   94306.00000                                  b''      nan
# 1275   94459.00000                                  b''      nan
# 1664   94729.00000                                  b''      nan
# 1767   94784.00000                                  b''      nan
# ...

# %%
# drop rows with null days

rx_dx_df = rx_dx_df.loc[rx_dx_df['RXDDAYS'].isnull()==False]

# %%
rx_dx_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14309 entries, 0 to 14433
# Data columns (total 3 columns):
# SEQN       14309 non-null float64
# RXDRSD1    14309 non-null object
# RXDDAYS    14309 non-null float64
# dtypes: float64(2), object(1)
# memory usage: 447.2+ KB

# %%
rx_dx_df['RXDDRUG'] = rx_dx_df['RXDDRUG'].map(lambda x: x.decode("utf-8"))
rx_dx_df['RXDRSD1'] = rx_dx_df['RXDRSD1'].map(lambda x: x.decode("utf-8"))
# Out:
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
rx_dx_df
# Out:
#                               RXDDRUG                              RXDRSD1  \
# 0
# 1
# 2      ENALAPRIL; HYDROCHLOROTHIAZIDE     Essential (primary) hypertension
# 3                           MELOXICAM    Rheumatoid arthritis, unspecified
# 4                          OMEPRAZOLE                            Heartburn
# ...                               ...                                  ...
# 19638                      CETIRIZINE                 Allergy, unspecified
# 19639                      DULOXETINE        Anxiety disorder, unspecified
# 19640               FLUTICASONE NASAL     Other seasonal allergic rhinitis
# 19641                      GABAPENTIN  Neuralgia and neuritis, unspecified
# 19642                   NORTRIPTYLINE  Neuralgia and neuritis, unspecified
#
#          RXDDAYS
# 0            nan
# 1            nan
# 2     5475.00000
# 3       61.00000
# 4     3650.00000
# ...          ...
# 19638    4.00000
# 19639  365.00000
# 19640    4.00000
# 19641  365.00000
# ...

# %%
rx_dx_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19643 entries, 0 to 19642
# Data columns (total 3 columns):
# RXDDRUG    19643 non-null object
# RXDRSD1    19643 non-null object
# RXDDAYS    14309 non-null float64
# dtypes: float64(1), object(2)
# memory usage: 460.5+ KB

# %%
questions

# %%
file_list = '''ACQ_J.XPT	DEMO_J.XPT	KIQ_U_J.XPT	P_DEMO.XPT	SMQRTU_J.XPT
ALQ_J.XPT	DIQ_J.XPT	MCQ_J.XPT	RHQ_J.XPT	SMQSHS_J.XPT
AUQ_J.XPT	DUQ_J.XPT	OCQ_J.XPT	RXQASA_J.XPT	SMQ_J.XPT
BPQ_J.XPT	ECQ_J.XPT	OHQ_J.XPT	RXQ_RX_J.XPT	VTQ_J.XPT
CDQ_J.XPT	HEQ_J.XPT	OSQ_J.XPT	SLQ_J.XPT	WHQMEC_J.XPT
DBQ_J.XPT	HSQ_J.XPT	P_BPXO.XPT	SMQFAM_J.XPT	WHQ_J.XPT'''.split(	)

# %%
file_list

# %%
name_list = [x.rstrip('.XPT') for x in file_list]
name_list

# %%
file_tuples = dict(zip(name_list, file_list))

# %%
file_tuples

# %%
for key in file_tuples:
    key.lower() = pd.DataFrame()
